# %%
import pandas as pd

file_paths = [
    '/Users/vincent/Downloads/terrier-project-5.5/var/evalNoPorterNoStop/BM25_1-50',
    '/Users/vincent/Downloads/terrier-project-5.5/var/evalNoPorterNoStop/BM25_51-100',
    '/Users/vincent/Downloads/terrier-project-5.5/var/evalNoPorterNoStop/BM25_101-150',
]

metrics_of_interest = ['num_q', 'num_ret', 'num_rel', 'num_rel_ret', 'map', 'gm_map', 'Rprec', 'bpref', 'recip_rank', 'P_1000']

columns = ['Model', 'Query Range', 'Number of Queries', 'Number of Documents Retrieved', 'Number of Relevant Documents', 'Number of Relevant Documents Retrieved', 'MAP', 'GM_MAP', 'R-Precision', 'Bpref', 'Reciprocal Rank','P_1000']
data_list = []

for file_path in file_paths:
    model = "BM25" if "BM25" in file_path else "Dirichlet"
    query_range = "1-50" if "1-50" in file_path else "51-100" if "51-100" in file_path else "101-150"

    with open(file_path, 'r') as file:
        lines = file.readlines()

    data = {metric: None for metric in metrics_of_interest}
    for line in lines:
        split_line = line.split("\t")
        metric_name = split_line[0].strip()
        if metric_name in metrics_of_interest:
            data[metric_name] = float(split_line[2].strip())

    data_list.append({
        'Model': model,
        'Query Range': query_range,
        'Number of Queries': data['num_q'],
        'Number of Documents Retrieved': data['num_ret'],
        'Number of Relevant Documents': data['num_rel'],
        'Number of Relevant Documents Retrieved': data['num_rel_ret'],
        'MAP': data['map'],
        'GM_MAP': data['gm_map'],
        'R-Precision': data['Rprec'],
        'Bpref': data['bpref'],
        'Reciprocal Rank': data['recip_rank'],
        'P_1000': data['P_1000']
    })

summarized_data = pd.DataFrame(data_list, columns=columns)
summarized_data
# Out:
#   Model Query Range  Number of Queries  Number of Documents Retrieved  \
# 0  BM25        1-50               50.0                        50000.0
# 1  BM25      51-100               50.0                        50000.0
# 2  BM25     101-150               50.0                        50000.0
#
#    Number of Relevant Documents  Number of Relevant Documents Retrieved  \
# 0                        3720.0                                  1125.0
# 1                       11946.0                                  4045.0
# 2                        9873.0                                  3085.0
#
#       MAP  GM_MAP  R-Precision   Bpref  Reciprocal Rank  P_1000
# 0  0.0736  0.0045       0.0962  0.2462           0.1979  0.0225
# 1  0.1439  0.0180       0.1856  0.2578           0.3894  0.0809
# 2  0.1089  0.0252       0.1617  0.2202           0.4048  0.0617

# %%
import pandas as pd

file_paths = [
    '/Users/vincent/Downloads/terrier-project-5.5/var/evalPorterNoStop/BM25_1-50',
    '/Users/vincent/Downloads/terrier-project-5.5/var/evalPorterNoStop/BM25_51-100',
    '/Users/vincent/Downloads/terrier-project-5.5/var/evalPorterNoStop/BM25_100-150',
]

metrics_of_interest = ['num_q', 'num_ret', 'num_rel', 'num_rel_ret', 'map', 'gm_map', 'Rprec', 'bpref', 'recip_rank', 'P_1000']

columns = ['Model', 'Query Range', 'Number of Queries', 'Number of Documents Retrieved', 'Number of Relevant Documents', 'Number of Relevant Documents Retrieved', 'MAP', 'GM_MAP', 'R-Precision', 'Bpref', 'Reciprocal Rank','P_1000']
data_list = []

for file_path in file_paths:
    model = "BM25" if "BM25" in file_path else "Dirichlet"
    query_range = "1-50" if "1-50" in file_path else "51-100" if "51-100" in file_path else "101-150"

    with open(file_path, 'r') as file:
        lines = file.readlines()

    data = {metric: None for metric in metrics_of_interest}
    for line in lines:
        split_line = line.split("\t")
        metric_name = split_line[0].strip()
        if metric_name in metrics_of_interest:
            data[metric_name] = float(split_line[2].strip())

    data_list.append({
        'Model': model,
        'Query Range': query_range,
        'Number of Queries': data['num_q'],
        'Number of Documents Retrieved': data['num_ret'],
        'Number of Relevant Documents': data['num_rel'],
        'Number of Relevant Documents Retrieved': data['num_rel_ret'],
        'MAP': data['map'],
        'GM_MAP': data['gm_map'],
        'R-Precision': data['Rprec'],
        'Bpref': data['bpref'],
        'Reciprocal Rank': data['recip_rank'],
        'P_1000': data['P_1000']
    })

summarized_data = pd.DataFrame(data_list, columns=columns)
summarized_data
# Out:
#   Model Query Range  Number of Queries  Number of Documents Retrieved  \
# 0  BM25        1-50               50.0                        50000.0
# 1  BM25      51-100               50.0                        50000.0
# 2  BM25     101-150               50.0                        50000.0
#
#    Number of Relevant Documents  Number of Relevant Documents Retrieved  \
# 0                        3720.0                                  1195.0
# 1                       11946.0                                  4576.0
# 2                        9873.0                                  3489.0
#
#       MAP  GM_MAP  R-Precision   Bpref  Reciprocal Rank  P_1000
# 0  0.0917  0.0035       0.1066  0.2487           0.2092  0.0239
# 1  0.1648  0.0221       0.2112  0.2920           0.3477  0.0915
# 2  0.1044  0.0194       0.1650  0.2294           0.3033  0.0698

# %%
import pandas as pd

file_paths = [
    '/Users/vincent/Downloads/terrier-project-5.5/var/evalPorterStop/BM25_1-50',
    '/Users/vincent/Downloads/terrier-project-5.5/var/evalPorterStop/BM25_51-100',
    '/Users/vincent/Downloads/terrier-project-5.5/var/evalPorterStop/BM25_100-150',
    '/Users/vincent/Downloads/terrier-project-5.5/var/evalPorterStop/DIRICHLET_1-50',
    '/Users/vincent/Downloads/terrier-project-5.5/var/evalPorterStop/DIRICHLET_51-100',
    '/Users/vincent/Downloads/terrier-project-5.5/var/evalPorterStop/DIRICHLET_101-150',
    '/Users/vincent/Downloads/terrier-project-5.5/var/evalPorterStop/TF_IDF_1-50',
    '/Users/vincent/Downloads/terrier-project-5.5/var/evalPorterStop/TF_IDF_51-100',
    '/Users/vincent/Downloads/terrier-project-5.5/var/evalPorterStop/TF_IDF_101-150'
]

metrics_of_interest = ['num_q', 'num_ret', 'num_rel', 'num_rel_ret', 'map', 'gm_map', 'Rprec', 'bpref', 'recip_rank', 'P_1000']

columns = ['Model', 'Query Range', 'Number of Queries', 'Number of Documents Retrieved', 'Number of Relevant Documents', 'Number of Relevant Documents Retrieved', 'MAP', 'GM_MAP', 'R-Precision', 'Bpref', 'Reciprocal Rank','P_1000']
data_list = []

for file_path in file_paths:
    model = "BM25" if "BM25" in file_path else "Dirichlet" if "DIRICHLET" in file_path else "TF_IDF"
    query_range = "1-50" if "1-50" in file_path else "51-100" if "51-100" in file_path else "101-150"

    with open(file_path, 'r') as file:
        lines = file.readlines()

    data = {metric: None for metric in metrics_of_interest}
    for line in lines:
        split_line = line.split("\t")
        metric_name = split_line[0].strip()
        if metric_name in metrics_of_interest:
            data[metric_name] = float(split_line[2].strip())

    data_list.append({
        'Model': model,
        'Query Range': query_range,
        'Number of Queries': data['num_q'],
        'Number of Documents Retrieved': data['num_ret'],
        'Number of Relevant Documents': data['num_rel'],
        'Number of Relevant Documents Retrieved': data['num_rel_ret'],
        'MAP': data['map'],
        'GM_MAP': data['gm_map'],
        'R-Precision': data['Rprec'],
        'Bpref': data['bpref'],
        'Reciprocal Rank': data['recip_rank'],
        'P_1000': data['P_1000']
    })

summarized_data = pd.DataFrame(data_list, columns=columns)
summarized_data
# Out:
#        Model Query Range  Number of Queries  Number of Documents Retrieved  \
# 0       BM25        1-50               50.0                        50000.0
# 1       BM25      51-100               50.0                        50000.0
# 2       BM25     101-150               50.0                        50000.0
# 3  Dirichlet        1-50               50.0                        50000.0
# 4  Dirichlet      51-100               50.0                        50000.0
# 5  Dirichlet     101-150               50.0                        50000.0
# 6     TF_IDF        1-50               50.0                        50000.0
# 7     TF_IDF      51-100               50.0                        50000.0
# 8     TF_IDF     101-150               50.0                        50000.0
#
#    Number of Relevant Documents  Number of Relevant Documents Retrieved  \
# 0                        3720.0                                  1332.0
# 1                       11946.0                                  4651.0
# ...

# %%
# Data for the new table as provided
data_for_new_table = {
    "System Model": [
        "TERRIER Porter+ Stoplist BM25", "TERRIER Porter+ Stoplist BM25", "TERRIER Porter+ Stoplist BM25",
        "TERRIER Porter+ Stoplist TF-IDF", "TERRIER Porter+ Stoplist TF-IDF", "TERRIER Porter+ Stoplist TF-IDF",
        "TERRIER Porter+ Stoplist DIRICHLET", "TERRIER Porter+ Stoplist DIRICHLET", "TERRIER Porter+ Stoplist DIRICHLET",
        "TERRIER Porter+ Stoplist LONG QUERRIES +BM25", "TERRIER Porter+ Stoplist LONG QUERRIES +BM25", "TERRIER Porter+ Stoplist LONG QUERRIES +BM25",
        "SOLR Porter+ Stoplist BM25", "SOLR Porter+ Stoplist BM25", "SOLR Porter+ Stoplist BM25",
        "SOLR Porter+ Stoplist TF-IDF", "SOLR Porter+ Stoplist TF-IDF", "SOLR Porter+ Stoplist TF-IDF",
        "Galago Stoplist, Krovetz BM25", "Galago Stoplist, Krovetz BM25", "Galago Stoplist, Krovetz BM25",
        "Galago Stoplist, Krovetz DIRICHLET", "Galago Stoplist, Krovetz DIRICHLET", "Galago Stoplist, Krovetz DIRICHLET"
    ],
    "Index": [
        "1-50", "51-100", "101-150",
        "1-50", "51-100", "101-150",
        "1-50", "51-100", "101-150",
        "1-50", "51-100", "101-150",
        "1-50", "51-100", "101-150",
        "1-50", "51-100", "101-150",
        "1-50", "51-100", "101-150",
        "1-50", "51-100", "101-150"
    ],
    "MAP": [
        0.0930, 0.1688, 0.1466,
        0.0977, 0.1726, 0.1606,
        0.0753, 0.1149, 0.1052,
        0.2326, 0.3225, 0.3540,
        0.0656, 0.1812, 0.0536,
        0.0656, 0.1813, 0.0536,
        0.0838, 0.2021, 0.1941,
        0.0871, 0.1968, 0.1943
    ]
}

# Creating a DataFrame from the data
df_new = pd.DataFrame(data_for_new_table)

# Pivot the DataFrame to the format requested
df_pivot = df_new.pivot_table(index='System Model', columns='Index', values='MAP', aggfunc='first')

# Calculate the MAP Mean
df_pivot['MAP MEAN'] = df_pivot.mean(axis=1)

df_pivot.reset_index()  # Reset index to include System Model as a column
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 36
#       2 data_for_new_table = {
#       3     "System Model": [
#       4         "TERRIER Porter+ Stoplist BM25", "TERRIER Porter+ Stoplist BM25", "TERRIER Porter+ Stoplist BM25",
#    (...)
#      32     ]
#      33 }
#      35 # Creating a DataFrame from the data
# ---> 36 df_new = pd.DataFrame(data_for_new_table)
#      38 # Pivot the DataFrame to the format requested
#      39 df_pivot = df_new.pivot_table(index='System Model', columns='Index', values='MAP', aggfunc='first')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

file_paths = [
    '/Users/vincent/Downloads/terrier-project-5.5/var/evalPorterStopWithNarrDesc/BM25_1-50',
    '/Users/vincent/Downloads/terrier-project-5.5/var/evalPorterStopWithNarrDesc/BM25_51-100',
    '/Users/vincent/Downloads/terrier-project-5.5/var/evalPorterStopWithNarrDesc/BM25_101-150',
]

metrics_of_interest = ['num_q', 'num_ret', 'num_rel', 'num_rel_ret', 'map', 'gm_map', 'Rprec', 'bpref', 'recip_rank', 'P_1000']

columns = ['Model', 'Query Range', 'Number of Queries', 'Number of Documents Retrieved', 'Number of Relevant Documents', 'Number of Relevant Documents Retrieved', 'MAP', 'GM_MAP', 'R-Precision', 'Bpref', 'Reciprocal Rank','P_1000']
data_list = []

for file_path in file_paths:
    model = "BM25" if "BM25" in file_path else "Dirichlet" if 
    query_range = "1-50" if "1-50" in file_path else "51-100" if "51-100" in file_path else "101-150"

    with open(file_path, 'r') as file:
        lines = file.readlines()

    data = {metric: None for metric in metrics_of_interest}
    for line in lines:
        split_line = line.split("\t")
        metric_name = split_line[0].strip()
        if metric_name in metrics_of_interest:
            data[metric_name] = float(split_line[2].strip())

    data_list.append({
        'Model': model,
        'Query Range': query_range,
        'Number of Queries': data['num_q'],
        'Number of Documents Retrieved': data['num_ret'],
        'Number of Relevant Documents': data['num_rel'],
        'Number of Relevant Documents Retrieved': data['num_rel_ret'],
        'MAP': data['map'],
        'GM_MAP': data['gm_map'],
        'R-Precision': data['Rprec'],
        'Bpref': data['bpref'],
        'Reciprocal Rank': data['recip_rank'],
        'P_1000': data['P_1000']
    })

summarized_data = pd.DataFrame(data_list, columns=columns)
summarized_data
# Out:
#   Model Query Range  Number of Queries  Number of Documents Retrieved  \
# 0  BM25        1-50               50.0                        50000.0
# 1  BM25      51-100               50.0                        50000.0
# 2  BM25     101-150               50.0                        50000.0
#
#    Number of Relevant Documents  Number of Relevant Documents Retrieved  \
# 0                        3720.0                                  2801.0
# 1                       11946.0                                  7239.0
# 2                        9873.0                                  7179.0
#
#       MAP  GM_MAP  R-Precision   Bpref  Reciprocal Rank  P_1000
# 0  0.2326  0.0830       0.2628  0.3615           0.5616  0.0560
# 1  0.3225  0.1702       0.3708  0.3873           0.7430  0.1448
# 2  0.3540  0.2583       0.3895  0.3959           0.7464  0.1436

# %%
import pandas as pd

file_paths = [
    '/Users/vincent/Downloads/terrier-project-5.5/var/eval_solr/BM25_1-50.eval',
    '/Users/vincent/Downloads/terrier-project-5.5/var/eval_solr/BM25_51-100.eval',
    '/Users/vincent/Downloads/terrier-project-5.5/var/eval_solr/BM25_101-150.eval',
    '/Users/vincent/Downloads/terrier-project-5.5/var/eval_solr/TFIDF_1-50.eval',
    '/Users/vincent/Downloads/terrier-project-5.5/var/eval_solr/TFIDF_51-100.eval',
    '/Users/vincent/Downloads/terrier-project-5.5/var/eval_solr/TFIDF_101-150.eval',
]

metrics_of_interest = ['num_q', 'num_ret', 'num_rel', 'num_rel_ret', 'map', 'gm_map', 'Rprec', 'bpref', 'recip_rank', 'P_1000']

columns = ['Model', 'Query Range', 'Number of Queries', 'Number of Documents Retrieved', 'Number of Relevant Documents', 'Number of Relevant Documents Retrieved', 'MAP', 'GM_MAP', 'R-Precision', 'Bpref', 'Reciprocal Rank','P_1000']
data_list = []

for file_path in file_paths:
    model = "BM25" if "BM25" in file_path else "TF_IDF"
    query_range = "1-50" if "1-50" in file_path else "51-100" if "51-100" in file_path else "101-150"

    with open(file_path, 'r') as file:
        lines = file.readlines()

    data = {metric: None for metric in metrics_of_interest}
    for line in lines:
        split_line = line.split("\t")
        metric_name = split_line[0].strip()
        if metric_name in metrics_of_interest:
            data[metric_name] = float(split_line[2].strip())

    data_list.append({
        'Model': model,
        'Query Range': query_range,
        'Number of Queries': data['num_q'],
        'Number of Documents Retrieved': data['num_ret'],
        'Number of Relevant Documents': data['num_rel'],
        'Number of Relevant Documents Retrieved': data['num_rel_ret'],
        'MAP': data['map'],
        'GM_MAP': data['gm_map'],
        'R-Precision': data['Rprec'],
        'Bpref': data['bpref'],
        'Reciprocal Rank': data['recip_rank'],
        'P_1000': data['P_1000']
    })

summarized_data = pd.DataFrame(data_list, columns=columns)
summarized_data
# Out:
#     Model Query Range  Number of Queries  Number of Documents Retrieved  \
# 0    BM25        1-50               19.0                         3419.0
# 1    BM25      51-100               18.0                         3876.0
# 2    BM25     101-150               10.0                         2606.0
# 3  TF_IDF        1-50               19.0                         3419.0
# 4  TF_IDF      51-100               18.0                         3876.0
# 5  TF_IDF     101-150               10.0                         2606.0
#
#    Number of Relevant Documents  Number of Relevant Documents Retrieved  \
# 0                        2517.0                                   222.0
# 1                        5053.0                                  1360.0
# 2                        2279.0                                   154.0
# 3                        2517.0                                   222.0
# 4                        5053.0                                  1362.0
# ...

# %%
import pandas as pd

file_paths = [
    '/Users/vincent/Downloads/terrier-project-5.5/var/eval_Galago/krovetz/BM25_1-50.eval',
    '/Users/vincent/Downloads/terrier-project-5.5/var/eval_Galago/krovetz/BM25_51-100.eval',
    '/Users/vincent/Downloads/terrier-project-5.5/var/eval_Galago/krovetz/BM25_101-150.eval',
    '/Users/vincent/Downloads/terrier-project-5.5/var/eval_Galago/krovetz/DIRICHLET_1-50.eval',
    '/Users/vincent/Downloads/terrier-project-5.5/var/eval_Galago/krovetz/DIRICHLET_51-100.eval',
    '/Users/vincent/Downloads/terrier-project-5.5/var/eval_Galago/krovetz/DIRICHLET_101-150.eval',
]

metrics_of_interest = ['num_q', 'num_ret', 'num_rel', 'num_rel_ret', 'map', 'gm_map', 'Rprec', 'bpref', 'recip_rank', 'P_1000']

columns = ['Model', 'Query Range', 'Number of Queries', 'Number of Documents Retrieved', 'Number of Relevant Documents', 'Number of Relevant Documents Retrieved', 'MAP', 'GM_MAP', 'R-Precision', 'Bpref', 'Reciprocal Rank','P_1000']
data_list = []

for file_path in file_paths:
    model = "BM25" if "BM25" in file_path else "DIRICHLET"
    query_range = "1-50" if "1-50" in file_path else "51-100" if "51-100" in file_path else "101-150"

    with open(file_path, 'r') as file:
        lines = file.readlines()

    data = {metric: None for metric in metrics_of_interest}
    for line in lines:
        split_line = line.split("\t")
        metric_name = split_line[0].strip()
        if metric_name in metrics_of_interest:
            data[metric_name] = float(split_line[2].strip())

    data_list.append({
        'Model': model,
        'Query Range': query_range,
        'Number of Queries': data['num_q'],
        'Number of Documents Retrieved': data['num_ret'],
        'Number of Relevant Documents': data['num_rel'],
        'Number of Relevant Documents Retrieved': data['num_rel_ret'],
        'MAP': data['map'],
        'GM_MAP': data['gm_map'],
        'R-Precision': data['Rprec'],
        'Bpref': data['bpref'],
        'Reciprocal Rank': data['recip_rank'],
        'P_1000': data['P_1000']
    })

summarized_data = pd.DataFrame(data_list, columns=columns)
summarized_data
# Out:
#        Model Query Range  Number of Queries  Number of Documents Retrieved  \
# 0       BM25        1-50                6.0                         6000.0
# 1       BM25      51-100               49.0                        45659.0
# 2       BM25     101-150               49.0                        49000.0
# 3  DIRICHLET        1-50                6.0                         6000.0
# 4  DIRICHLET      51-100               49.0                        45659.0
# 5  DIRICHLET     101-150               49.0                        49000.0
#
#    Number of Relevant Documents  Number of Relevant Documents Retrieved  \
# 0                         609.0                                   279.0
# 1                       11482.0                                  4672.0
# 2                        9839.0                                  4445.0
# 3                         609.0                                   288.0
# 4                       11482.0                                  4650.0
# ...

# %%
# Data for the new table as provided
data_for_new_table = {
    "System Model": [
        "TERRIER Porter+ Stoplist BM25", "TERRIER Porter+ Stoplist BM25", "TERRIER Porter+ Stoplist BM25",
        "TERRIER Porter+ Stoplist TF-IDF", "TERRIER Porter+ Stoplist TF-IDF", "TERRIER Porter+ Stoplist TF-IDF",
        "TERRIER Porter+ Stoplist DIRICHLET", "TERRIER Porter+ Stoplist DIRICHLET", "TERRIER Porter+ Stoplist DIRICHLET",
        "TERRIER Porter+ Stoplist LONG QUERRIES +BM25", "TERRIER Porter+ Stoplist LONG QUERRIES +BM25", "TERRIER Porter+ Stoplist LONG QUERRIES +BM25",
        "SOLR Porter+ Stoplist BM25", "SOLR Porter+ Stoplist BM25", "SOLR Porter+ Stoplist BM25",
        "SOLR Porter+ Stoplist TF-IDF", "SOLR Porter+ Stoplist TF-IDF", "SOLR Porter+ Stoplist TF-IDF",
        "Galago Stoplist, Krovetz BM25", "Galago Stoplist, Krovetz BM25", "Galago Stoplist, Krovetz BM25",
        "Galago Stoplist, Krovetz DIRICHLET", "Galago Stoplist, Krovetz DIRICHLET", "Galago Stoplist, Krovetz DIRICHLET"
    ],
    "Index": [
        "1-50", "51-100", "101-150",
        "1-50", "51-100", "101-150",
        "1-50", "51-100", "101-150",
        "1-50", "51-100", "101-150",
        "1-50", "51-100", "101-150",
        "1-50", "51-100", "101-150",
        "1-50", "51-100", "101-150",
        "1-50", "51-100", "101-150"
    ],
    "MAP": [
        0.0930, 0.1688, 0.1466,
        0.0977, 0.1726, 0.1606,
        0.0753, 0.1149, 0.1052,
        0.2326, 0.3225, 0.3540,
        0.0656, 0.1812, 0.0536,
        0.0656, 0.1813, 0.0536,
        0.0838, 0.2021, 0.1941,
        0.0871, 0.1968, 0.1943
    ]
}

# Creating a DataFrame from the data
df_new = pd.DataFrame(data_for_new_table)

# Pivot the DataFrame to the format requested
df_pivot = df_new.pivot_table(index='System Model', columns='Index', values='MAP', aggfunc='first')

# Calculate the MAP Mean
df_pivot['MAP MEAN'] = df_pivot.mean(axis=1)

df_pivot.reset_index()  # Reset index to include System Model as a column
# Out:
# Index                                  System Model    1-50  101-150  51-100  \
# 0                     Galago Stoplist, Krovetz BM25  0.0838   0.1941  0.2021
# 1                Galago Stoplist, Krovetz DIRICHLET  0.0871   0.1943  0.1968
# 2                        SOLR Porter+ Stoplist BM25  0.0656   0.0536  0.1812
# 3                      SOLR Porter+ Stoplist TF-IDF  0.0656   0.0536  0.1813
# 4                     TERRIER Porter+ Stoplist BM25  0.0930   0.1466  0.1688
# 5                TERRIER Porter+ Stoplist DIRICHLET  0.0753   0.1052  0.1149
# 6      TERRIER Porter+ Stoplist LONG QUERRIES +BM25  0.2326   0.3540  0.3225
# 7                   TERRIER Porter+ Stoplist TF-IDF  0.0977   0.1606  0.1726
#
# Index  MAP MEAN
# 0      0.160000
# 1      0.159400
# 2      0.100133
# 3      0.100167
# 4      0.136133
# 5      0.098467
# 6      0.303033
# 7      0.143633

# %%
# Box plot for the distribution of MAP scores for each system
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14, 8))

# We need to melt the dataframe to have a proper format for sns.boxplot
melted_data = pd.melt(df_final_new, id_vars=['System'], value_vars=['1-50', '51-100', '101-150'], 
                      var_name='Topic Range', value_name='MAP Score')

# Plotting the box plot with seaborn for better aesthetics and grouped by 'System'


sns.boxplot(x='System', y='MAP Score', data=melted_data)
plt.title('Box Plot of MAP Scores for Each System')
plt.ylabel('MAP Score')
plt.xlabel('System')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Box plot for the distribution of MAP scores for each system
# ----> 2 import matplotlib.pyplot as plt
#       3 import seaborn as sns
#       5 plt.figure(figsize=(14, 8))
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Data
data = {
    "System": [
        "Galago Krovetz BM25", 
        "Galago Krovetz DIRICHLET", 
        "SOLR  BM25", 
        "SOLR  TF-IDF", 
        "TERRIER  BM25", 
        "TERRIER  DIRICHLET", 
        "TERRIER LONG_QUERRIES+BM25", 
        "TERRIER  TF-IDF"
    ],
    "MAP 1-50": [0.0838, 0.0871, 0.0656, 0.0656, 0.0930, 0.0753, 0.2326, 0.0977],
    "MAP 51-100": [0.2021, 0.1968, 0.1812, 0.1813, 0.1688, 0.1149, 0.3225, 0.1726],
    "MAP 101-150": [0.1941, 0.1943, 0.0536, 0.0536, 0.1466, 0.1052, 0.3540, 0.1606],
    "MAP MEAN": [0.1600, 0.1594, 0.1001, 0.1002, 0.1361, 0.0985, 0.3030, 0.1436]
}

# Create DataFrame
df = pd.DataFrame(data)

# Melt the DataFrame for seaborn
melted_df = pd.melt(df, id_vars=["System"], value_vars=["MAP 1-50", "MAP 51-100", "MAP 101-150"],
                    var_name="Topic Range", value_name="MAP Score")

# Plotting the box plot
plt.figure(figsize=(14, 8))

sns.boxplot(x='System', y='MAP Score', data=melted_df, palette='Set3')
plt.title('Box Plot of MAP Scores for Each System')
plt.ylabel('MAP Score')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# /var/folders/d8/8148_d095wvfh6g9dkj2p3pc0000gn/T/ipykernel_4807/2937999376.py:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='System', y='MAP Score', data=melted_df, palette='Set3')

# %%
# First, let's organize the provided data into a pandas DataFrame
time_data = {
    "System Model": [
        "TERRIER Porter+ Stoplist BM25", "TERRIER Porter+ Stoplist BM25", "TERRIER Porter+ Stoplist BM25",
        "TERRIER Porter+ Stoplist TF-IDF", "TERRIER Porter+ Stoplist TF-IDF", "TERRIER Porter+ Stoplist TF-IDF",
        "TERRIER Porter+ Stoplist DIRICHLET", "TERRIER Porter+ Stoplist DIRICHLET", "TERRIER Porter+ Stoplist DIRICHLET",
        "TERRIER Porter+ Stoplist LONG QUERRIES +BM25", "TERRIER Porter+ Stoplist LONG QUERRIES +BM25", "TERRIER Porter+ Stoplist LONG QUERRIES +BM25",
        "SOLR Porter+ Stoplist BM25", "SOLR Porter+ Stoplist BM25", "SOLR Porter+ Stoplist BM25",
        "SOLR Porter+ Stoplist TF-IDF", "SOLR Porter+ Stoplist TF-IDF", "SOLR Porter+ Stoplist TF-IDF",
        "Galago Stoplist, Krovetz BM25", "Galago Stoplist, Krovetz BM25", "Galago Stoplist, Krovetz BM25",
        "Galago Stoplist, Krovetz DIRICHLET", "Galago Stoplist, Krovetz DIRICHLET", "Galago Stoplist, Krovetz DIRICHLET"
    ],
    "Index": [
        "1-50", "51-100", "101-150",
        "1-50", "51-100", "101-150",
        "1-50", "51-100", "101-150",
        "1-50", "51-100", "101-150",
        "1-50", "51-100", "101-150",
        "1-50", "51-100", "101-150",
        "1-50", "51-100", "101-150",
        "1-50", "51-100", "101-150"
    ],
    "Time": [
        2562, 1716, 2306,
        1382, 1157, 3228,
        2529, 1904, 3412,
        10296, 7844, 10779,
        186, 287, 107,
        104, 664, 693,
        1862, 4584, 4424,
        1592, 4921, 5682
    ]
}

# Create DataFrame from the data
df_time = pd.DataFrame(time_data)

# Pivot the DataFrame to get the times per topic range for each model
df_time_pivot = df_time.pivot_table(index='System Model', columns='Index', values='Time', aggfunc='first')

# Calculate the Time Mean across the topic ranges for each model
df_time_pivot['TIME MEAN'] = df_time_pivot.mean(axis=1)

# Resetting the index to turn multi-index into columns
df_time_final = df_time_pivot.reset_index()

# Splitting 'System Model' into 'System' and 'Model' and adjusting the DataFrame
df_time_final[['System', 'Model']] = df_time_final['System Model'].str.rsplit(' ', 1, expand=True)
df_time_final.drop('System Model', axis=1, inplace=True)

# Reordering the columns to match the requested format
df_time_final = df_time_final[['System', 'Model', '1-50', '51-100', '101-150', 'TIME MEAN']]

# Display the final DataFrame
df_time_final
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 48
#      45 df_time_final = df_time_pivot.reset_index()
#      47 # Splitting 'System Model' into 'System' and 'Model' and adjusting the DataFrame
# ---> 48 df_time_final[['System', 'Model']] = df_time_final['System Model'].str.rsplit(' ', 1, expand=True)
#      49 df_time_final.drop('System Model', axis=1, inplace=True)
#      51 # Reordering the columns to match the requested format
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/core/strings/accessor.py:129, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     124     msg = (
#     125         f"Cannot use .str.{func_name} with values of "
#     126         f"inferred dtype '{self._inferred_dtype}'."
#     127     )
#     128     raise TypeError(msg)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Data
time_data = {
    "System Model": [
        "TERRIER Porter+ Stoplist BM25", "TERRIER Porter+ Stoplist BM25", "TERRIER Porter+ Stoplist BM25",
        "TERRIER Porter+ Stoplist TF-IDF", "TERRIER Porter+ Stoplist TF-IDF", "TERRIER Porter+ Stoplist TF-IDF",
        "TERRIER Porter+ Stoplist DIRICHLET", "TERRIER Porter+ Stoplist DIRICHLET", "TERRIER Porter+ Stoplist DIRICHLET",
        "TERRIER Porter+ Stoplist LONG QUERRIES +BM25", "TERRIER Porter+ Stoplist LONG QUERRIES +BM25", "TERRIER Porter+ Stoplist LONG QUERRIES +BM25",
        "SOLR Porter+ Stoplist BM25", "SOLR Porter+ Stoplist BM25", "SOLR Porter+ Stoplist BM25",
        "SOLR Porter+ Stoplist TF-IDF", "SOLR Porter+ Stoplist TF-IDF", "SOLR Porter+ Stoplist TF-IDF",
        "Galago Stoplist, Krovetz BM25", "Galago Stoplist, Krovetz BM25", "Galago Stoplist, Krovetz BM25",
        "Galago Stoplist, Krovetz DIRICHLET", "Galago Stoplist, Krovetz DIRICHLET", "Galago Stoplist, Krovetz DIRICHLET"
    ],
    "Index": ["1-50", "51-100", "101-150"] * 8,
    "Time": [
        2562, 1716, 2306,
        1382, 1157, 3228,
        2529, 1904, 3412,
        10296, 7844, 10779,
        186, 287, 107,
        104, 664, 693,
        1862, 4584, 4424,
        1592, 4921, 5682
    ]
}

# Create DataFrame from the data
df_time = pd.DataFrame(time_data)

# Pivot the DataFrame to get the times per topic range for each model
df_time_pivot = df_time.pivot_table(index='System Model', columns='Index', values='Time', aggfunc='first')

# Calculate the Time Mean across the topic ranges for each model
df_time_pivot['TIME MEAN'] = df_time_pivot.mean(axis=1)

# Resetting the index to turn multi-index into columns
df_time_final = df_time_pivot.reset_index()

# Correctly splitting 'System Model' into 'System' and 'Model'
df_time_final[['System', 'Indexing']] = df_time_final['System Model'].str.rsplit(' ', n=1, expand=True)

# Dropping the now unnecessary 'System Model' column
df_time_final.drop('System Model', axis=1, inplace=True)

# Melting the DataFrame for plotting
melted_time_data = pd.melt(df_time_final, id_vars=['System', 'Indexing'], value_vars=['1-50', '51-100', '101-150', 'TIME MEAN'], 
                           var_name='Topic Range', value_name='Time Score')

# Box plot for the distribution of Time scores for each system
plt.figure(figsize=(14, 8))
sns.boxplot(x='System', y='Time Score', hue='Indexing', data=melted_time_data, palette='Set3')
plt.title('Box Plot of Time Scores for Each System')
plt.ylabel('Time Score (milliseconds)')
plt.xlabel('System')
plt.xticks(rotation=45)
plt.legend(title='Indexing', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Data
time_data = {
    "System Model": [
        "TERRIER Porter+ Stoplist BM25", "TERRIER Porter+ Stoplist BM25", "TERRIER Porter+ Stoplist BM25",
        "TERRIER Porter+ Stoplist TF-IDF", "TERRIER Porter+ Stoplist TF-IDF", "TERRIER Porter+ Stoplist TF-IDF",
        "TERRIER Porter+ Stoplist DIRICHLET", "TERRIER Porter+ Stoplist DIRICHLET", "TERRIER Porter+ Stoplist DIRICHLET",
        "TERRIER Porter+ Stoplist LONG QUERRIES +BM25", "TERRIER Porter+ Stoplist LONG QUERRIES +BM25", "TERRIER Porter+ Stoplist LONG QUERRIES +BM25",
        "SOLR Porter+ Stoplist BM25", "SOLR Porter+ Stoplist BM25", "SOLR Porter+ Stoplist BM25",
        "SOLR Porter+ Stoplist TF-IDF", "SOLR Porter+ Stoplist TF-IDF", "SOLR Porter+ Stoplist TF-IDF",
        "Galago Stoplist, Krovetz BM25", "Galago Stoplist, Krovetz BM25", "Galago Stoplist, Krovetz BM25",
        "Galago Stoplist, Krovetz DIRICHLET", "Galago Stoplist, Krovetz DIRICHLET", "Galago Stoplist, Krovetz DIRICHLET"
    ],
    "Index": ["1-50", "51-100", "101-150"] * 8,
    "Time": [
        2562, 1716, 2306,
        1382, 1157, 3228,
        2529, 1904, 3412,
        10296, 7844, 10779,
        186, 287, 107,
        104, 664, 693,
        1862, 4584, 4424,
        1592, 4921, 5682
    ]
}

# Create DataFrame from the data
df_time = pd.DataFrame(time_data)

# Pivot the DataFrame to get the times per topic range for each model
df_time_pivot = df_time.pivot_table(index='System Model', columns='Index', values='Time', aggfunc='first')

# Calculate the Time Mean across the topic ranges for each model
df_time_pivot['TIME MEAN'] = df_time_pivot.mean(axis=1)

# Resetting the index to turn multi-index into columns
df_time_final = df_time_pivot.reset_index()

# Correctly splitting 'System Model' into 'System' and 'Model'
df_time_final['System'] = df_time_final['System Model'].apply(lambda x: " ".join(x.split()[:-1]))
df_time_final['Model'] = df_time_final['System Model'].apply(lambda x: x.split()[-1])

# Dropping the now unnecessary 'System Model' column
df_time_final.drop('System Model', axis=1, inplace=True)

# Reordering the columns to match the requested format
columns_order = ['System', 'Model', '1-50', '51-100', '101-150', 'TIME MEAN']
df_time_final = df_time_final[columns_order]

# Display the final DataFrame
df_time_final
# Out:
# Index                                  System      Model   1-50  51-100  \
# 0                    Galago Stoplist, Krovetz       BM25   1862    4584
# 1                    Galago Stoplist, Krovetz  DIRICHLET   1592    4921
# 2                       SOLR Porter+ Stoplist       BM25    186     287
# 3                       SOLR Porter+ Stoplist     TF-IDF    104     664
# 4                    TERRIER Porter+ Stoplist       BM25   2562    1716
# 5                    TERRIER Porter+ Stoplist  DIRICHLET   2529    1904
# 6      TERRIER Porter+ Stoplist LONG QUERRIES      +BM25  10296    7844
# 7                    TERRIER Porter+ Stoplist     TF-IDF   1382    1157
#
# Index  101-150    TIME MEAN
# 0         4424  3623.333333
# 1         5682  4065.000000
# 2          107   193.333333
# 3          693   487.000000
# 4         2306  2194.666667
# 5         3412  2615.000000
# 6        10779  9639.666667
# 7         3228  1922.333333

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Constructing the DataFrame from the provided data
data = {
    "System": [
        "Galago", "Galago Krovetz+",
        "SOLR", "SOLR",
        "TERRIER ", "TERRIER ",
        "TERRIER+LONG QUERRIES", "TERRIER"
    ],
    "Model": [
        "BM25", "DIRICHLET",
        "BM25", "TF-IDF",
        "BM25", "DIRICHLET",
        "+BM25", "TF-IDF"
    ],
    "TIME 1-50": [1862, 1592, 186, 104, 2562, 2529, 10296, 1382],
    "TIME 51-100": [4584, 4921, 287, 664, 1716, 1904, 7844, 1157],
    "TIME 101-150": [4424, 5682, 107, 693, 2306, 3412, 10779, 3228],
    "TIME MEAN": [3623.33, 4065.00, 193.33, 487.00, 2194.67, 2615.00, 9639.67, 1922.33]
}

df = pd.DataFrame(data)

# Melting the DataFrame to prepare for plotting
melted_df = pd.melt(df, id_vars=["System", "Model"], value_vars=["TIME 1-50", "TIME 51-100", "TIME 101-150", "TIME MEAN"],
                    var_name="Time Range", value_name="Time Score")

# Generating the box plot
plt.figure(figsize=(14, 8))
sns.boxplot(x='System', y='Time Score', hue='Time Range', data=melted_df, palette='Set3')
plt.title('Distribution of Time Scores for Each System')
plt.ylabel('Time Score (milliseconds)')
plt.xlabel('System')
plt.xticks(rotation=45)
plt.legend(title='Time Range', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Data
data = {
    "System": [
        "Galago Krovetz BM25", 
        "Galago Krovetz DIRICHLET", 
        "SOLR  BM25", 
        "SOLR  TF-IDF", 
        "TERRIER  BM25", 
        "TERRIER  DIRICHLET", 
        "TERRIER LONG_QUERRIES+BM25", 
        "TERRIER  TF-IDF"
    ],
     "TIME 1-50": [1862, 1592, 186, 104, 2562, 2529, 10296, 1382],
    "TIME 51-100": [4584, 4921, 287, 664, 1716, 1904, 7844, 1157],
    "TIME 101-150": [4424, 5682, 107, 693, 2306, 3412, 10779, 3228],
    "TIME MEAN": [3623.33, 4065.00, 193.33, 487.00, 2194.67, 2615.00, 9639.67, 1922.33]
}

# Create DataFrame
df = pd.DataFrame(data)

# Melt the DataFrame for seaborn
melted_df = pd.melt(df, id_vars=["System"], value_vars=["TIME 1-50", "TIME 51-100", "TIME 101-150"],
                    var_name="Topic Range", value_name="Retriving Time")

# Plotting the box plot
plt.figure(figsize=(14, 8))

sns.boxplot(x='System', y='Retriving Time', data=melted_df, palette='Set3')
plt.title('Box Plot of Retriving Time for Each System')
plt.ylabel('Retriving Time')
plt.xlabel('System')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# /var/folders/d8/8148_d095wvfh6g9dkj2p3pc0000gn/T/ipykernel_6603/2942771764.py:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='System', y='Retriving Time', data=melted_df, palette='Set3')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Data preparation
new_graph_data = pd.DataFrame({
    "System": [
        "Galago Krovetz BM25", "Galago Krovetz DIRICHLET",
        "SOLR BM25", "SOLR TF-IDF",
        "TERRIER BM25", "TERRIER DIRICHLET",
        "TERRIER LONG QUERRIES+BM25", "TERRIER TF-IDF"
    ],
    "MAP MEAN": [0.1600, 0.1594, 0.1001, 0.1002, 0.1361, 0.0985, 0.3030, 0.1436],
    "TIME MEAN": [3623.33, 4065.00, 193.33, 487.00, 2194.67, 2615.00, 9639.67, 1922.33]
})

# Creating a unique color for each system
unique_systems = new_graph_data['System'].unique()
color_palette = sns.color_palette('tab10', len(unique_systems))
system_color_dict = {system: color_palette[i] for i, system in enumerate(unique_systems)}

# Plotting
plt.figure(figsize=(14, 8))

# Plot each system with its unique color
for system, color in system_color_dict.items():
    system_data = new_graph_data[new_graph_data['System'].str.contains(system.split()[0])]
    plt.scatter(system_data['MAP MEAN'], system_data['TIME MEAN'], color=color, label=system, s=100)

    # Annotate each point with the system model
    for _, row in system_data.iterrows():
        plt.text(row['MAP MEAN'] + 0.002, row['TIME MEAN'], row['System'].split()[-1],
                 horizontalalignment='left', size='medium', color='black', weight='semibold')

plt.title('MAP MEAN vs. TIME MEAN for Each System')
plt.xlabel('MAP MEAN')
plt.ylabel('TIME MEAN (milliseconds)')
plt.legend(title='System', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Data preparation
new_graph_data = pd.DataFrame({
    "System": [
        "Galago Krovetz BM25", "Galago Krovetz DIRICHLET",
        "SOLR BM25", "SOLR TF-IDF",
        "TERRIER BM25", "TERRIER DIRICHLET",
        "TERRIER LONG QUERRIES+BM25", "TERRIER TF-IDF"
    ],
    "MAP MEAN": [0.1600, 0.1594, 0.1001, 0.1002, 0.1361, 0.0985, 0.3030, 0.1436],
    "TIME MEAN": [3623.33, 4065.00, 193.33, 487.00, 2194.67, 2615.00, 9639.67, 1922.33]
})

# Plotting
plt.figure(figsize=(14, 8))

# Generating a color palette with a unique color for each system
colors = sns.color_palette('tab10', n_colors=new_graph_data['System'].nunique())

# Scatter plot for MAP MEAN vs. TIME MEAN with unique colors for each system
for i, row in new_graph_data.iterrows():
    plt.scatter(x=row['MAP MEAN'], y=row['TIME MEAN'], color=colors[i % len(colors)], s=100, label=row['System'])

    # Annotating each point with its full system name
    plt.text(x=row['MAP MEAN'] + 0.002,  # Adding a small offset to x for readability
             y=row['TIME MEAN'],
             s=row['System'],
             fontdict=dict(color='black', size=10),
             bbox=dict(facecolor='white', alpha=0.5, boxstyle="round,pad=0.3"))

# Removing duplicate labels in the legend
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), title='System', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.title('MAP MEAN vs. TIME MEAN for Each System')
plt.xlabel('MAP MEAN')
plt.ylabel('TIME MEAN (milliseconds)')
plt.grid(True)
plt.tight_layout()
plt.show()
